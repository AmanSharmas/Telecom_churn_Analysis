# %% [markdown]
# <a href="https://colab.research.google.com/github/AmanSharmas/Capstone-project--1-/blob/main/Capstone_project_1_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Telecom Churn Analysis EDA

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Team
# ##### **Team Member 1 -** Aman Sharma
# ##### **Team Member 2 -** Mattaparty Harish
# ##### **Team Member 3 -** Pratik Thorat

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Exploratory Data Analysis (EDA) refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.
#
# EDA process involves:
#
# 1. Understanding the variables and the structure of the dataset is the initial stage in this process.
# 2. Data preprocessing and cleansing are critical components of EDA.
# 3. Identifying errors, detect outliers or anomalous events.
# 4. Examine the relationships among the variables.
# 5. Apart from the above, there is also the ‘Classification or Clustering analysis’ technique used in EDA. It is an unsupervised type of machine learning used for the classification of input data into specified categories or clusters exhibiting similar characteristics in various groups. This can be further used to draw important interpretations in EDA.
#
# Libraries used in Eda:
# 1. Pandas
# 2. Numpy
# 3. Matplotib
# 4. Seaborn
# 5. Plotly
#
# Graphs used for representation:
# 1. Bar plot
# 2. Pie plot
# 3. Box Plot
# 4. Grouped bar plot
# 5. Doughnut plot
# 6. Venn diagram
# 7. Heatmap
# 8. Pair plot
# 9. Scatter plot
#
# The telecom market in the US is saturated and customer growth rates are low. They key focus of market players therefore is on retention and churn control. This project explores the dataset to identify the key drivers of churn and grab key insights from the dataset.
#
# The insights gained from the dataset through the use of exploratory data analysis:
#
# 1. The four charge fields are linear functions of the minute fields.
# 2. The area code field is anomalous, and can be omitted.
# 3. The correlations among the remaining predictor variables are weak, allowing us to retain them all for any data mining model.
# 4. Customers making less than 6 International calls tend to churn more frequently.
# 5. Long duration callers have faced issues with the quality of service provided which is evident from the number of customer service calls made by them i.e. around 3 calls.
# 6. Customers with four or more customer service calls churn more often than others.
#
# Suggestions provided to reduce churn rate in the business:
#
# 1. Reduce the day call charges and can consider providing happy hour kind of offer when there is least call traffic during the day.
#
# 2. Customers opting international plans are quite low (only 9.69%) so there is quite huge market to capture.
#
# 3. Only 28% percent of customers have opted for voice mail plan which can marketed further for increasing revenue.
#
# 3. Provide better customer support & rebate on call tariffs to International callers for better retention as acquiring newer customer is 5 times costlier than retaining the old ones.
#
# 4. States where the churn rate is quite high due to more customer service calls, In such states West Virginia customer support model can be adopted as the number of services calls were highest but churn has been comparitively quite lower.
#
# 5. Maximum churn percentage is observed in long duration calls & service calls made by long duration callers is upto 3 calls hence improvement in the service provided is a essential measure.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# 1) Aman Sharma - https://github.com/AmanSharmas/Capstone-project--1-
#
# 2) Mattaparty Harish - https://github.com/Harishkmr33/Capstone-Project-1
#
# 3) Pratik Thorat - https://github.com/Pratik94229/Capstone-Project-1

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Orange S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer cancelled the subscription. Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To reduce churn rate and increase profit of Orange S.A.

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import seaborn as sns
import plotly.graph_objects as px
import plotly.express as x
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
#Mounting drive on colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# # Loading Dataset as df
df = pd.read_csv('/content/drive/MyDrive/Alma Better/Module 1/Capstone project 1/Telecom Churn.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
#Checking column names
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
#Checking shape of the dataframe
df.shape
# Out:
# (3333, 20)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
dup_df = df[df.duplicated()].count()
dup_df
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_df = df[df.isna()].count()
null_df
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# DataFrame has no null values.

# %%
# Visualizing the missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %% [markdown]
# No missing values are found from the dataset.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ####1) Dataset contains 3333 rows & 20 columns.
# ####2) Dataset has no Null/Duplicate values.
# ####3) Only Churn column has boolean values, which indicates weather the customer has churned or not.
# ####4) All States are divided by three Area codes which are common.
# ####5) The values in column international plan and voice mail plan are yes or no which can be considerd as boolean values for analytical purpose.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * **State                :** Has different states of US i.e. 51 states.
#
# * **Account Length       :** Active duration of account.
#
# * **Area Code            :** Area code of different states.
#
# * **lntl Plan            :** International plan activation status. ( Yes/No )
#
# * **VMail Plan           :** Voice Mail plan activation status. ( Yes/No )
#
# * **VMail Message        :** No. of voice mail messages recieved.
#
# * **Day Mins             :** Duration of calls during day in Mins.
#
# * **Day calls**         : No. of calls made during day time.
#
# * **Day Charge**         : Charges of calls during day.
#
# * **Eve Mins**          : Duration of calls during evening in Mins.
#
# * **Eve Calls**          : No. of calls made during evening time.
#
# * **Eve Charge**         : Charges of calls during evening.
#
# * **Night Mins**         : Duration of calls during night in Mins.
#
# * **Night Calls**        :  No. of calls made during night time.
#
# * **Night Charge**      : Charges of calls during night.
#
# * **Intl Mins**         : Duration of International calls in Mins.
#
# * **Intl Calls**         : No. of International calls made.
#
# * **Intl Charge**        : Charges of International calls.
#
# * **CustServ calls**    : No. of customer service calls made.
#
# * **Churn**             : Whether the Customer has churned. (True/False)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns:
  print(f"Unique {i}'s count:{df[i].nunique()}")
  print(f"{df[i].unique()}\n")
# Out:
# Unique State's count:51
# ['KS' 'OH' 'NJ' 'OK' 'AL' 'MA' 'MO' 'LA' 'WV' 'IN' 'RI' 'IA' 'MT' 'NY'
#  'ID' 'VT' 'VA' 'TX' 'FL' 'CO' 'AZ' 'SC' 'NE' 'WY' 'HI' 'IL' 'NH' 'GA'
#  'AK' 'MD' 'AR' 'WI' 'OR' 'MI' 'DE' 'UT' 'CA' 'MN' 'SD' 'NC' 'WA' 'NM'
#  'NV' 'DC' 'KY' 'ME' 'MS' 'TN' 'PA' 'CT' 'ND']
#
# Unique Account length's count:212
# [128 107 137  84  75 118 121 147 117 141  65  74 168  95  62 161  85  93
#   76  73  77 130 111 132 174  57  54  20  49 142 172  12  72  36  78 136
#  149  98 135  34 160  64  59 119  97  52  60  10  96  87  81  68 125 116
#   38  40  43 113 126 150 138 162  90  50  82 144  46  70  55 106  94 155
#   80 104  99 120 108 122 157 103  63 112  41 193  61  92 131 163  91 127
#  110 140  83 145  56 151 139   6 115 146 185 148  32  25 179  67  19 170
#  164  51 208  53 105  66  86  35  88 123  45 100 215  22  33 114  24 101
#  143  48  71 167  89 199 166 158 196 209  16  39 173 129  44  79  31 124
# ...

# %% [markdown]
# ## ***3. Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Creating a copy of original dataframe
new_df = df.copy()
# Adding a new column customer id 
new_df.insert(0,'Customer_id',list(range(1,3334)))

# %%
# Adding a new column Average call duration
new_df['avg_calls_duration'] = (new_df['Total night minutes'] + new_df["Total day minutes"]+new_df["Total eve minutes"])/(new_df['Total night calls']+new_df['Total day calls']+new_df['Total eve calls'])

# %%
# Sorting out customers on the basis of duration of call
def call_type(length):
  if length > 2.5:
    return 'long'
  elif length > 1.9:
    return 'medium'
  else:
    return 'short'

new_df['Call_duration'] = new_df['avg_calls_duration'].apply(lambda x: call_type(x))

# %%
# Sorting out customers on the basis of no. days of subscription.

def customer_type(length):
  if length >=120:
    return 'old'
  elif length > 75:
    return 'intermediate'
  else:
    return 'new'

# Adding a new column Customer type based on the above separation
new_df['customer_type']=new_df['Account length'].apply(customer_type)

# %%
# Checking first 5 rows of our dataframe
new_df.head()
# Out:
#    Customer_id State  Account length  Area code International plan  \
# 0            1    KS             128        415                 No
# 1            2    OH             107        415                 No
# 2            3    NJ             137        415                 No
# 3            4    OH              84        408                Yes
# 4            5    OK              75        415                Yes
#
#   Voice mail plan  Number vmail messages  Total day minutes  Total day calls  \
# 0             Yes                     25              265.1              110
# 1             Yes                     26              161.6              123
# 2              No                      0              243.4              114
# 3              No                      0              299.4               71
# 4              No                      0              166.7              113
#
#    Total day charge  ...  Total night calls  Total night charge  \
# ...

# %%
# Grouping by Churn & calculating mean values for rest of the columns.
churn_count = df.groupby('Churn')
churn_count.mean()
# Out:
# <ipython-input-223-cd3d39069d38>:3: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#        Account length   Area code  Number vmail messages  Total day minutes  \
# Churn
# False      100.793684  437.074737               8.604561         175.175754
# True       102.664596  437.817805               5.115942         206.914079
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# Churn
# False       100.283158         29.780421         199.043298       100.038596
# True        101.335404         35.175921         212.410145       100.561077
#
#        Total eve charge  Total night minutes  Total night calls  \
# Churn
# False         16.918909           200.133193         100.058246
# True          18.054969           205.231677         100.399586
#
# ...

# %%
copy_df = df.copy()

def convert_to_bool(elem):
  
  if elem == 'Yes':
    return True
  else:
    return False

copy_df['International_plan_bool'] = copy_df['International plan'].apply(lambda x: convert_to_bool(x))
copy_df['Voice_mail_plan_bool'] = copy_df['Voice mail plan'].apply(lambda x: convert_to_bool(x))

# %%
# Checking outliers in Customer service calls
fig = x.box(new_df, y="Customer service calls")
fig.update_layout(autosize=False,width=400,height=400,title="Customer service calls :")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Checking outliers in Customer Account length
fig = x.box(new_df, y='Account length')
fig.update_layout(autosize=False,width=400,height=400,title="Customer Account length :")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. Added a new column as customer id as values present in it are serial numbers from 1 to 3333.
# 2. More number of customer services have been made among the churned customers.
# 3. Added a new column as "avg_calls_duration" which is average duration of total calls &	"Call_duration" on the basis of duration of call, criteria for sorting is
#                      ----> Above 2.5, Long duration
#                      ----> In between 1.9 to 2.5, Medium duration
#                      ----> Below 1.9, Short duration
#
# 4. Added a new column as "customer_type" on the basis of days of subscription, criteria for sorting is
#                      ----> Above 120, old customer
#                      ----> In between 75 & 120, intermediate
#                      ----> Below 75, new
# 5. We have created a copy of dataframe and converted international plan and voice mail plans into boolean values to find corelations.
#
# 6. Outliers related to customer account length is ignored by taking them as old customers as that can be a possible scenario.
#
# 7. Similarly outliers in customer service calls are ignored as there might be more number of calls due to poorer service.

# %% [markdown]
# ### Data Wrangling Code Continuation

# %%
#Comparing customer types with churn
# customer_type_vs_churn= new_df.groupby(['customer_type'])["Churn"].value_counts().unstack()
customer_type_vs_churn= new_df.groupby(['customer_type'])["Churn"].value_counts().unstack()
customer_type_vs_churn.reset_index(inplace = True)
customer_type_vs_churn['total customer'] = customer_type_vs_churn[0]+customer_type_vs_churn[1]
customer_type_vs_churn['churn percentage'] = round(100*(customer_type_vs_churn[1] / customer_type_vs_churn['total customer']),2)
customer_type_vs_churn
# Out:
# Churn customer_type  False  True  total customer  churn percentage
# 0      intermediate   1161   210            1371             15.32
# 1               new    771   118             889             13.27
# 2               old    918   155            1073             14.45

# %%
#Checking customer distribution in states on basis of customer type
customer_type1=new_df.groupby('State')['customer_type'].value_counts().unstack()
customer_type1 = customer_type1.reset_index().rename(columns = {"State":"States"})
statewise_customers = new_df['State'].value_counts().reset_index().rename(columns = {'index':'States','State':'No. of customers'})
state_wise_type_of_C = pd.merge(customer_type1,statewise_customers,on='States')
state_wise_type_of_C.head()
# Out:
#   States  intermediate  new  old  No. of customers
# 0     AK            19   16   17                52
# 1     AL            37   21   22                80
# 2     AR            31   13   11                55
# 3     AZ            32   15   17                64
# 4     CA            17    8    9                34

# %%
# Getting statewise churn percentage.
users_statewise_churn=new_df.groupby('State')['Churn'].value_counts().unstack()
users_statewise_churn.reset_index(inplace = True)
users_statewise_churn['total_customer'] = users_statewise_churn[0]+users_statewise_churn[1]
users_statewise_churn['churn percentage'] = round(100*(users_statewise_churn[1]/users_statewise_churn['total_customer']),2)
users_statewise_churn.sort_values(by = 'churn percentage',ascending = False,inplace = True)
users_statewise_churn = users_statewise_churn.reset_index()
users_statewise_churn.rename(columns ={False:'churn_False',True:'churn_True'},inplace = True)
users_statewise_churn.head()
# Out:
# Churn  index State  churn_False  churn_True  total_customer  churn percentage
# 0         31    NJ           50          18              68             26.47
# 1          4    CA           25           9              34             26.47
# 2         43    TX           54          18              72             25.00
# 3         20    MD           53          17              70             24.29
# 4         40    SC           46          14              60             23.33

# %%
# International plans subscribers
international_plans = new_df['International plan'].value_counts().reset_index().rename(columns = {'index':'International_plan_opted','International plan':'Subscribers'})
international_plans['percentage'] = international_plans['Subscribers'].apply(lambda x : round((x/3333)*100,2))
international_plans
# Out:
#   International_plan_opted  Subscribers  percentage
# 0                       No         3010       90.31
# 1                      Yes          323        9.69

# %%
# Voice Mail plans subscribers
voicemail_plans = new_df['Voice mail plan'].value_counts().reset_index().rename(columns = {'index':'Vmail_plan_opted','Voice mail plan':'Subscribers'})
voicemail_plans['percentage'] = voicemail_plans['Subscribers'].apply(lambda x : round((x/3333)*100,2))
voicemail_plans
# Out:
#   Vmail_plan_opted  Subscribers  percentage
# 0               No         2411       72.34
# 1              Yes          922       27.66

# %%
# Customers who subscribed both plans
persons_who_subscribe_both_plans = new_df.groupby(['Voice mail plan','International plan'])["Customer_id"].count()
persons_who_subscribe_both_plans.unstack()
# Out:
# International plan    No  Yes
# Voice mail plan
# No                  2180  231
# Yes                  830   92

# %%
# Finding out relation between number of minutes & calls for customers with international plans
inter_calls_churn = new_df[(new_df['International plan'] == 'Yes') & (new_df["Total intl calls"] <= 5)][['Total intl calls','Total intl minutes','Churn']]
inter_calls_churn.sort_values(by ='Total intl minutes', ignore_index = True,inplace = True)
inter_calls_churn
# Out:
#      Total intl calls  Total intl minutes  Churn
# 0                   4                 2.1  False
# 1                   5                 3.7  False
# 2                   2                 4.1   True
# 3                   2                 4.3   True
# 4                   4                 4.5  False
# ..                ...                 ...    ...
# 221                 4                16.9   True
# 222                 2                16.9   True
# 223                 5                17.5   True
# 224                 4                17.6   True
# 225                 3                17.9   True
#
# [226 rows x 3 columns]

# %%
#Churn Distribution on international callers with less number of calls
inter_calls_churn = inter_calls_churn['Churn'].value_counts().reset_index().rename(columns = {"index" : "Churn","Churn":"Churn_counts"})
inter_calls_churn['percentage'] = inter_calls_churn['Churn_counts'].apply(lambda x : round((x/226)*100,2))
inter_calls_churn
# Out:
#    Churn  Churn_counts  percentage
# 0  False           123       54.42
# 1   True           103       45.58

# %%
#Churn Distribution on basis of call duration type
data_by_duration = new_df.groupby(['Call_duration','Churn'])["Churn"].count().unstack()
data_by_duration = data_by_duration.reset_index()
data_by_duration['total'] = data_by_duration[True] + data_by_duration[False]
data_by_duration['Churn_percentage'] = round((data_by_duration[True]/data_by_duration['total'])*100,2)
data_by_duration.rename(columns = {True:"Churned_true",False:'Churned_false'},inplace = True)
data_by_duration
# Out:
# Churn Call_duration  Churned_false  Churned_true  total  Churn_percentage
# 0              long            199            81    280             28.93
# 1            medium           1276           236   1512             15.61
# 2             short           1375           166   1541             10.77

# %%
# Churn percentage on the basis of number of customer service calls.
Churn_vs_calls=new_df.groupby('Customer service calls')["Churn"].value_counts()
Churn_vs_calls=Churn_vs_calls.unstack().reset_index().fillna(0)
Churn_vs_calls['percentage_churn']=(Churn_vs_calls[1]/(Churn_vs_calls[1]+Churn_vs_calls[0]))*100
Churn_vs_calls
# Out:
# Churn  Customer service calls   False   True  percentage_churn
# 0                           0   605.0   92.0         13.199426
# 1                           1  1059.0  122.0         10.330229
# 2                           2   672.0   87.0         11.462451
# 3                           3   385.0   44.0         10.256410
# 4                           4    90.0   76.0         45.783133
# 5                           5    26.0   40.0         60.606061
# 6                           6     8.0   14.0         63.636364
# 7                           7     4.0    5.0         55.555556
# 8                           8     1.0    1.0         50.000000
# 9                           9     0.0    2.0        100.000000

# %%
#Distribution of call length on the basis customer service calls
call_duration_vs_customer_support=new_df.groupby(['Call_duration','Customer service calls'])["Customer service calls"].count().unstack().transpose()
call_duration_vs_customer_support=call_duration_vs_customer_support.reset_index()
call_duration_vs_customer_support['long_callers_percentage']=round((((call_duration_vs_customer_support['long'])/280)*100),2)
call_duration_vs_customer_support.head()
# Out:
# Call_duration  Customer service calls  long  medium  short  \
# 0                                   0  70.0   306.0  321.0
# 1                                   1  96.0   544.0  541.0
# 2                                   2  54.0   341.0  364.0
# 3                                   3  42.0   195.0  192.0
# 4                                   4  13.0    79.0   74.0
#
# Call_duration  long_callers_percentage
# 0                                25.00
# 1                                34.29
# 2                                19.29
# 3                                15.00
# 4                                 4.64

# %%
#checking out relation between voice mails & chrun
voice_mail_churn = new_df[(new_df['Voice mail plan'] == 'Yes')][['Number vmail messages','Churn']]
voice_mail_churn.sort_values(by ='Number vmail messages', ignore_index = True,inplace = True)
voice_mail_churn.head()
# Out:
#    Number vmail messages  Churn
# 0                      4  False
# 1                      8  False
# 2                      8  False
# 3                      9  False
# 4                      9  False

# %%
# Churn percentage among voice mail subscribers
voice_mail_churn = voice_mail_churn['Churn'].value_counts().reset_index().rename(columns = {"index" : "Churn","Churn":"Churn_counts"})
voice_mail_churn['percentage'] = voice_mail_churn['Churn_counts'].apply(lambda x : round((x/922)*100,2))
voice_mail_churn
# Out:
#    Churn  Churn_counts  percentage
# 0  False           842       91.32
# 1   True            80        8.68

# %%
#Finding out total charges in different periods of day
total_charge = new_df[["Total night charge","Total day charge","Total eve charge",'Total intl charge']].sum().reset_index().rename(columns = {'index':'charges',0:'Total_charges'})
total_charge
# Out:
#               charges  Total_charges
# 0  Total night charge       30128.07
# 1    Total day charge      101864.17
# 2    Total eve charge       56939.44
# 3   Total intl charge        9214.35

# %%
#Finding out total minutes in different periods of day
total_min = new_df[["Total night minutes","Total day minutes","Total eve minutes",'Total intl minutes']].sum().reset_index().rename(columns = {0:"Total_min","index" :'mins'},)
total_min
# Out:
#                   mins  Total_min
# 0  Total night minutes   669506.5
# 1    Total day minutes   599190.4
# 2    Total eve minutes   669867.5
# 3   Total intl minutes    34120.9

# %%
#finding out charges per minute in different duration of day
charges_per_min = pd.concat([total_charge,total_min],axis = 1)
charges_per_min['charges per min'] = round(charges_per_min['Total_charges']/charges_per_min['Total_min'],3)
charges_per_min.drop(['mins','charges'],axis = 1,inplace = True)
charges_df = charges_per_min.rename(index = {0:"Night",1:"Day",2:"Evening",3:"International"}).sort_values(by = 'charges per min',ascending = False)
charges_df = charges_df.reset_index().rename(columns = {"index":"Charge type"})
charges_df
# Out:
#      Charge type  Total_charges  Total_min  charges per min
# 0  International        9214.35    34120.9            0.270
# 1            Day      101864.17   599190.4            0.170
# 2        Evening       56939.44   669867.5            0.085
# 3          Night       30128.07   669506.5            0.045

# %%
#Finding out total charges by state
columns_charge = ["Total night charge","Total day charge","Total eve charge",'Total intl charge']
total_charges = new_df.groupby(['State'])[columns_charge].sum()
total_charges_statewise = total_charges.sum(axis = 1).reset_index().rename(columns={0:"total_charges"}).sort_values(by='total_charges',ascending = False,ignore_index = True)
total_charges_statewise.head()
# Out:
#   State  total_charges
# 0    WV        6079.48
# 1    MN        5071.19
# 2    NY        4843.77
# 3    AL        4755.43
# 4    OH        4733.69

# %%
# Finding out total mins by each state.
columns_mins = ['Total night minutes','Total day minutes','Total eve minutes']
total_mins = new_df.groupby(['State'])[columns_mins].sum()
total_mins_statewise = total_mins.sum(axis = 1).reset_index().rename(columns={0:"total_mins"}).sort_values(by='total_mins',ascending = False,ignore_index = True)
total_mins_statewise.head()
# Out:
#   State  total_mins
# 0    WV     59722.5
# 1    MN     49759.1
# 2    NY     47756.3
# 3    OH     46348.1
# 4    VA     45770.7

# %%
# Finding out number of churn vs Customer service calls.
chruns_by_states = new_df.groupby(by = ['State'])[['Churn','Customer service calls']].sum().sort_values(by = 'Customer service calls',ascending = False).reset_index()
chruns_by_states.head()
# Out:
#   State  Churn  Customer service calls
# 0    WV     10                     159
# 1    NY     15                     142
# 2    OR     11                     135
# 3    MN     15                     130
# 4    VT      8                     127

# %%
# Mergeing total_mins_statewise and chruns_by_states.
merged_min_df = pd.merge(total_mins_statewise,chruns_by_states, on ='State')
merged_df = pd.merge(total_charges_statewise,merged_min_df, on = 'State')
merged_df['charges_per_mins'] = merged_df['total_charges']/merged_df['total_mins']
final_df = pd.merge(merged_df,users_statewise_churn,on = 'State')
final_df.drop(final_df.columns[[3,6,7,8]], axis=1, inplace=True)
final_df.sort_values(by = 'churn percentage',ascending = False,inplace = True)
final_df.head()
# Out:
#    State  total_charges  total_mins  Customer service calls  charges_per_mins  \
# 50    CA        2030.42     19755.5                      50          0.102777
# 18    NJ        4244.56     40861.1                     114          0.103878
# 16    TX        4282.55     41514.7                     116          0.103157
# 13    MD        4345.30     41433.3                     119          0.104875
# 37    SC        3443.28     34142.1                      95          0.100851
#
#     total_customer  churn percentage
# 50              34             26.47
# 18              68             26.47
# 16              72             25.00
# 13              70             24.29
# 37              60             23.33

# %%
# Adding new column total_calls. 
columns = ['State','Area code','Total day calls','Total eve calls','Total night calls','Total intl calls']
new_df['total_calls'] = new_df['Total day calls']+new_df['Total eve calls']+new_df['Total night calls']+new_df['Total intl calls']
new_df.groupby('State')['total_calls'].sum().reset_index().head()
# Out:
#   State  total_calls
# 0    AK        15288
# 1    AL        24070
# 2    AR        16705
# 3    AZ        19671
# 4    CA        10582

# %%
# dividing Customers and total_calls on the basis area code
customer_by_area_code =  new_df.groupby(['Area code']).agg({'Customer_id': 'count', 'total_calls': 'sum'})
customer_by_area_code
# Out:
#            Customer_id  total_calls
# Area code
# 408                838       254543
# 415               1655       506497
# 510                840       255982

# %%
# Churn by Area code.
customer_by_churn = new_df.groupby(['Area code','Churn'])['Churn'].count().unstack()
customer_by_churn = customer_by_churn.drop(customer_by_churn.columns[0],axis = 1)
customer_by_churn
# Out:
# Churn      True
# Area code
# 408         122
# 415         236
# 510         125

# %%
# churn percentage by area code.
churns_areawise = pd.merge(customer_by_area_code,customer_by_churn,on = 'Area code').reset_index()
churns_areawise.rename(columns = {True:'churns_count','Customer_id':'Number_of_customers'},inplace = True)
churns_areawise['percentage'] = round(100*(churns_areawise['churns_count']/churns_areawise['Number_of_customers']),2)
churns_areawise
# Out:
#    Area code  Number_of_customers  total_calls  churns_count  percentage
# 0        408                  838       254543           122       14.56
# 1        415                 1655       506497           236       14.26
# 2        510                  840       255982           125       14.88

# %% [markdown]
# ## **4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables**

# %% [markdown]
# #### Chart - 1

# %%
# Customers opting for international plan
fig = x.bar(international_plans , x="International_plan_opted",y="Subscribers",title='Customers who opted for International plan',color='International_plan_opted', height=400,width=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar graph summarises the large set of data in simple visual form. It displays each category of data in the frequency distribution. It clarifies the trend of data better than the table. It helps in estimating the key values at a glance. As we are comparing customer churn rate with total number of customers so grouped bar chart is making it easy for visualizing data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Only around 10% of the total customers opted for International plan.

# %% [markdown]
# #### Chart - 2

# %%
# Customers opting for voice mail plan
fig = x.bar(voicemail_plans, x='Vmail_plan_opted',y="Subscribers",title='Customers who opted for Voicemail plan',color='Vmail_plan_opted', height=400,width=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. What is/are the insight(s) found from the chart?

# %% [markdown]
# Around 28% of the total customers opted for voice mail plans.
# So voice mail service is the most populer service opted by the customers.

# %% [markdown]
# #### Chart - 3

# %%
# Customers opting for both the plans
plt.figure(figsize=(10,10))
venn2(subsets = (922, 323, 92), set_labels = ('Voice mail plan', 'International plan'),set_colors=("blue","purple"),alpha = 0.6)
plt.title('Customers opting for both the plans')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Venn diagram uses overlapping circles or other shapes to illustrate the logical relationships between two or more sets of items. Often, they serve to graphically organize things, highlighting how the items are similar and different.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The customers who subscribed both plans are 92.

# %% [markdown]
# #### Chart - 4

# %%
# Customer Distribution by Type.
fig = px.Figure(data=[px.Pie(labels=['intermediate customer','new customer','old customer'],pull=[0.05],values= customer_type_vs_churn["total customer"], hole=.4)])
fig.update_layout(autosize=False,width=600,height=400,title="Customer Distribution by Type",legend_title_text = "Customer Type")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A doughnut chart shows the relationship of parts to a whole.doughnut charts can make it easier for users to compare individual dimensions. So we are showing customer distribution using this chart.

# %% [markdown]
# #####2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Relatively new customers(from 75 to 120) grab the greater chunk of customer distribution, followed by older customers.

# %% [markdown]
# #### Chart - 5

# %%
# Checking  churn by customer type
fig = px.Figure(data=[
    px.Bar(name='Total Customer', x=['intermediate customer','new customer','old customer'], y=customer_type_vs_churn['total customer']),
    px.Bar(name='Customer Churn', x=['intermediate customer','new customer','old customer'], y=customer_type_vs_churn[True])])

fig.update_layout(width=600,height=500,barmode='group',title = 'Chrun by Customer Type')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. What is/are the insight(s) found from the chart?

# %% [markdown]
# More percent of churns can be observed from the older & intermediate customers.

# %% [markdown]
# #### Chart - 6

# %%
#function for adding labels
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center',fontsize = 'x-large',fontweight = 'semibold')
        
#Finding total number of customers by its type
plt.figure(figsize=(20, 10))
plt.bar(state_wise_type_of_C['States'],state_wise_type_of_C['old'],color='#87CEFF',label = 'Old Customers')
plt.bar(state_wise_type_of_C['States'], state_wise_type_of_C["new"], bottom=state_wise_type_of_C["old"], color='#7B68EE',label = 'New Customers')
plt.bar(state_wise_type_of_C['States'], state_wise_type_of_C["intermediate"], bottom=state_wise_type_of_C["old"]+state_wise_type_of_C["new"], color='#00FA9A',label = 'Intermediate customers')
addlabels(state_wise_type_of_C['States'], state_wise_type_of_C['No. of customers'])
plt.legend()
plt.show()

# %%
#Sorted based on old customers.
state_wise_type_of_C.sort_values("old",ascending=False).head()
# Out:
#    States  intermediate  new  old  No. of customers
# 49     WV            38   36   32               106
# 23     MN            28   25   31                84
# 16     KS            23   17   30                70
# 34     NY            27   26   30                83
# 37     OR            25   23   30                78

# %%
#Sorted based on new customers.
state_wise_type_of_C.sort_values("new",ascending=False).head()
# Out:
#    States  intermediate  new  old  No. of customers
# 49     WV            38   36   32               106
# 26     MT            24   26   18                68
# 34     NY            27   26   30                83
# 23     MN            28   25   31                84
# 43     TX            24   24   24                72

# %%
#Sorted based on No. of customers.
state_wise_type_of_C.sort_values("No. of customers",ascending=False).head()
# Out:
#    States  intermediate  new  old  No. of customers
# 49     WV            38   36   32               106
# 23     MN            28   25   31                84
# 34     NY            27   26   30                83
# 1      AL            37   21   22                80
# 37     OR            25   23   30                78

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Stacked Bar charts are used to show how a larger category is divided into smaller subcategories and what the relationship of each part has on the total amount.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Out of 51 States, WV,MN,NY has maximum number of customers distibution respectively.WV,MT,NY has maximum number of new customer while states of WV,MN,KS has maximum number of old customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# CA,IA and PA have least number of customer base so these states can be targeted to capture new potential customers.

# %% [markdown]
# #### Chart - 7

# %%
#Statewise Customer & Churn Distribtion 
fig = px.Figure(data=[
    px.Bar(name='Total Customer', x=users_statewise_churn['State'], y=users_statewise_churn['total_customer']),
    px.Bar(name='Customer Churn', x=users_statewise_churn['State'], y=users_statewise_churn['churn_True'])
])
fig.update_layout(barmode='group',width=1100,height=500,title = 'Customer & Churn Distribution by states')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Grouped Bar graph summarises the large set of data in simple visual form. It displays each category of data in the frequency distribution. It clarifies the trend of data better than the table. It helps in estimating the key values at a glance. As we are comparing customer churn rate with total number of customers so grouped bar chart is making it easy for visualizing data.
# estimate key values at a glance.

# %% [markdown]
# #### Chart - 8

# %%
# Statewise churn percentage
fig = px.Figure(data=[px.Pie(labels=users_statewise_churn['State'],pull=[0.15,0.1,0.05],
                             values=users_statewise_churn['churn percentage'])])
fig.update_traces(hoverinfo='label', textinfo='value', textfont_size=10)
fig.update_layout(width=800,height=700,barmode='group',title = 'Customer churn percentage by states')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart is visually striking and easy to understand.
# The pie chart gives us an idea of the relative proportion for each category of data at a single glance.permit a visual check of the reasonableness or accuracy of calculations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Maximum percentage of churn rate can be observed from the states of New Jersey, California & Texas.

# %% [markdown]
# #### Chart - 9

# %%
# Churn rate among international subscribers with lower call counts.
fig = x.pie(inter_calls_churn, values='Churn_counts', names=['Not Churned(123)','Churned(103)'], title='Churn rate among international subscribers with lower call counts:')
fig.update_layout(autosize=True,width=650,height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. What is/are the insight(s) found from the chart?

# %% [markdown]
# For customers who made less than 6 international calls most likely to churned.

# %% [markdown]
# #### Chart - 10

# %%
# Churn rate among voice mail plan subscribers with lower mail count.
fig = x.pie(voice_mail_churn,values='Churn_counts',names=['Not Churned','Churned'], title='Churn rate among voice mail plan subscribers with lower mail count:')
fig.update_layout(autosize=True,width=650,height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The voice mail plan has almost negligible effect on churn rate.

# %% [markdown]
# #### Chart - 11

# %%
# Finding average Charges per mins on the basis of call types.
plt.figure(figsize=(10, 7))
plt.plot(charges_df["Charge type"], charges_df["charges per min"], color='pink', marker='o', linestyle='dashed',linewidth=2, markersize=50)
addlabels(charges_df['Charge type'], charges_df['charges per min'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart, also referred to as a line graph or a line plot, connects a series of data points using a line. This chart type presents sequential values to help you identify trends.It helps to determine the relationship between two sets of values, with one data set always being dependent on the other data set.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Call charges are maximum for international calls and lowest for local night calls.

# %% [markdown]
# #### Chart - 12

# %%
# Finding Customer service calls statewise.
fig = x.bar(final_df, x='State', y='Customer service calls',color = 'Customer service calls')
fig.update_layout(autosize=True,width=1200,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 1.What is/are the insight(s) found from the chart?

# %% [markdown]
# Maximium sevice calls are made from WV and NY but churn rate in WV is 9.43% and NY is 18.07%. This discrepancy in data set might be due to ability of customer service center to resolve customer issue.So it would be in best of interest of service provider to apply same model in other state as well to reduce overall churn rate.

# %% [markdown]
# #### Chart - 13

# %%
# ploting a correlation between Customer service calls and churn.
fig = x.scatter(chruns_by_states, x="Customer service calls", y="Churn", color="Churn",size='Churn',trendline="ols")
fig.update_layout(autosize=True,width=700,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot uses dots to represent values for two different numeric variables. Scatter plots are used to observe relationships between variables. A linear regression is a straight line representation of relationship between an independent and dependent variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It can be observed that churn rate is positively corelated to number of customer service calls made. It might be due to dissatisfaction with service provided or incapability of customer service centre to resolve customers issue.

# %% [markdown]
# #### Chart - 14

# %%
# Ploting churn percentage on the basis of call duration.
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.bar(data_by_duration['Call_duration'], data_by_duration['total'])
ax1.set_title('No. of customers on the basis of call duration')
ax1.set_ylim(0, 2000)

ax2.bar(data_by_duration['Call_duration'], data_by_duration['Churn_percentage'],color='red')
ax2.set_title('Churn Percentage on the basis of call duration')
ax2.set_ylim(0, 30)

plt.xticks(rotation=30, ha='right')
plt.show()

# %%
call_duration_vs_customer_support.head()
# Out:
# Call_duration  Customer service calls  long  medium  short  \
# 0                                   0  70.0   306.0  321.0
# 1                                   1  96.0   544.0  541.0
# 2                                   2  54.0   341.0  364.0
# 3                                   3  42.0   195.0  192.0
# 4                                   4  13.0    79.0   74.0
#
# Call_duration  long_callers_percentage
# 0                                25.00
# 1                                34.29
# 2                                19.29
# 3                                15.00
# 4                                 4.64

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above graphs it can be observed that maximum churn percentage is observed in long duration calls. Also it can be observed that service calls made by long duration callers is upto 3 calls and hence there might be possibility  that customer support were unable to resolve their issue leading to higher churn rate.

# %% [markdown]
# #### Chart - 15 - Correlation Heatmap

# %%
# Ploting Heat map.
corr_df = copy_df[['Account length','International_plan_bool','Voice_mail_plan_bool','Number vmail messages','Total day charge','Total night charge','Total eve charge','Total intl charge',
                  'Total day calls','Total eve calls','Total night calls','Total intl calls','Customer service calls', 'Churn']]
corr_df = corr_df.corr()
plt.figure(figsize=(17,10))
sns.heatmap(corr_df, vmin=-1, cmap='coolwarm', annot=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmaps are used to show relationships between two variables, one plotted on each axis. By observing how cell colors change across each axis, you can observe if there are any patterns in value for one or both variables.Since we want find relationship between diffrent variables in dataframe and heatmap can be one of the way to visualize it.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. There is no major effect on churn with the number of voice mail subscribers.
#
# 2. In above heatmap we can observe there is positive corelation between churn rate and international plan opted,total day charges and customer service calls.
# So it seems there churn rate is correlated with international plans due to high charges associated with the service.
#
# 3. Similarly same issue can be assumed for day calls. Also there is positive correlation of churn rate with customer service calls which might be due to inability of customer support to resolve customer issue which can also be observed in scattered plot where as number of customer support calls increases churn rate also increases.
#
# 4. So Orange SA. Should consider example from West Virgnia state where although customers service calls were higher still churn rate was low as customer service support might be providing reasonable support to the customer.

# %% [markdown]
# #### Chart - 16 - Pair Plot

# %%
# Plotting Pair Plot
n_df = final_df[['total_charges', 'total_mins', 'Customer service calls',
       'charges_per_mins', 'churn percentage']]
g = sns.pairplot(n_df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pairs plot allows us to see both distribution of single variables and relationships between two variables. Pair plots are a great method to identify trends for follow-up analysis and can be easily implemented in Python!

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above pair plot it is observed their is positive corelation between total number of mins and number of service calls.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective?

# %% [markdown]
# 1. Day charges are significantly higher than Night and Evening call charges which can be reason for higher churn rate, So it is suggested to reduce the day call charges and can consider providing happy hour kind of offer when there is least call traffic during the day.
#
# 2. Customers opting international plans are quite low (only 9.69%) so there is quite huge market to capture.
#
# 3. Only 28% percent of customers have opted for voice mail plan which can marketed further for increasing revenue.
#
# 3. Among the customers who have opted international plan & made lesser calls the churn rate is quite high (i.e 45.58%), so it is suggested to provide better customer support & rebate on call tariffs for better retention as acquiring newer customer is 5 times costlier than retaining the old ones.
#
# 4. It is observed that in few states the churn rate is quite high due to more customer service calls, In such states West Virginia customer support model can be adopted as the number of services calls were highest but churn has been comparitively quite lower.
#
# 5. It is observed that maximum churn percentage is observed in long duration calls & service calls made by long duration callers is upto 3 calls and hence there might be possibility that customer support were unable to resolve their issue leading to higher churn rate, So applying West Virginia support model is suggested to retain those customers.

# %% [markdown]
# ## **6. Conclusion**

# %% [markdown]
# 1.   Intermediate customer consumes highest share in dataset and has highest churn rate.
# 2. Voice mail plan subscription has almost negligible effect on churn rate.
# 3. Different churn rate observed in different state with maximum in New jersey.
#
# 4. High day charges seems to be one of reason for churn rate.
# 5. International plan subcribers making less calls are more likely to churn.
#
# 6. Number of Customer service calls made are positively correlated with customer churn rate.
# 7.   Long duration callers are more likely to churn.

# %% [markdown]
# ## **7. Limitations in analysis**

# %% [markdown]
# Limited dataset with similar distribution on call total day,eve and night charge,Total call mins
# weak positive correlation found between churn and total charges, total customer service calls

# %% [markdown]
# ## **8. Recommendation for Orange S.A. for future EDA**

# %% [markdown]
# Provide more data regarding customer like (age,sex,),internet service,payment method competitors information,congession hours and other important factors, we could draw more insights from the result.
